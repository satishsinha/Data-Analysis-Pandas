# %%
## Weather data set is a time-series data set with per hours information about the weather consitions of a particular area
## This records Temperature, relative humidity, wind speed, visibility, pressure and conditions.

# %%
import pandas as pd

# %%
data = pd.read_csv('weather.csv')

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
data.tail(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8774  12/31/2012 14:00    -3.4              -5.7         84                6
# 8775  12/31/2012 15:00    -2.3              -4.6         84                9
# 8776  12/31/2012 16:00    -1.4              -4.0         82               13
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
# 8778  12/31/2012 18:00    -1.3              -3.1         88               17
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8774           11.3     100.57    Snow
# 8775            9.7     100.47    Snow
# ...

# %%
data.shape
# Out:
# (8784, 8)

# %%
## this atributes provide index of the dataframe
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
## provide all columns
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
## Provide data types of every columns
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
## In columns, it shows all unique values. It can be applied only for single column, not in whole dataframe
data['Temp_C'].unique()
# Out:
# array([ -1.8,  -1.5,  -1.4,  -1.3,  -1. ,  -0.5,  -0.2,   0.2,   0.8,
#          1.8,   2.6,   3. ,   3.8,   3.1,   3.2,   4. ,   4.4,   5.3,
#          5.2,   4.6,   3.9,   3.7,   2.9,   2.3,   2. ,   1.9,   1.5,
#          2.2,   1.7,   1.1,   0. ,  -0.7,  -2.1,  -4.1,  -4.8,  -5.6,
#         -5.8,  -7. ,  -7.4,  -9. ,  -9.7, -10.5, -11.3, -12.6, -12.9,
#        -13.3, -14. , -14.8, -15. , -15.3, -14.9, -15.1, -15.8, -16.3,
#        -16.9, -17.3, -17. , -17.1, -17.5, -17.9, -18.1, -18.5, -18.6,
#        -18.2, -17.8, -16.8, -15.2, -14.2, -13.7, -12.4, -10.2,  -9.4,
#         -8.9,  -8.4,  -7.8,  -7.6,  -9.5,  -9.6,  -8.8,  -7.5,  -5.4,
#         -5. ,  -8.2,  -7.1,  -6.1,  -6.6,  -6. ,  -4.7,  -4.4,  -5.1,
#         -4.3,  -6.7,  -9.2,  -9.8,  -9.9, -10. , -10.6, -11.8, -12. ,
#        -14.4, -12.3, -12.5, -11.7, -11.9, -11.2, -11.5, -11.6,  -9.3,
#         -8.7,  -8.5,  -8.1,  -6.9,  -6.4,  -5.7,  -5.5,  -3.7,  -3.6,
# ...

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data['Weather'].unique().shape
# Out:
# (50,)

# %%
## In columns, it shows all unique values. It can be applied for single column, as well as whole dataframe
data['Temp_C'].nunique()
# Out:
# 533

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
## It shows count of not NaN values for every columns
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
# In a column, it shows all the unique values with their counts. It can be applied only for single column
data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data['Temp_C'].value_counts()
# Out:
# Temp_C
#  16.6    65
#  1.1     58
#  0.8     47
#  1.5     45
#  19.3    44
#          ..
# -20.7     1
# -21.0     1
#  31.8     1
#  32.6     1
# -21.3     1
# Name: count, Length: 533, dtype: int64

# %%
## Provide basic details about Dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
## Find unique value of wind speed
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
## Find unique wind speed and its counts- it short speed of wind
data['Wind Speed_km/h'].value_counts().sort_index(ascending=True)
# Out:
# Wind Speed_km/h
# 0     309
# 2       2
# 4     474
# 6     609
# 7     677
# 9     830
# 11    791
# 13    735
# 15    719
# 17    666
# 19    616
# 20    496
# 22    439
# 24    374
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 43     13
# 44     14
# 46     11
# 48     13
# 50      4
# 52      7
# 54      1
# 57      5
# 63      1
# 70      1
# 83      1
# Name: count, dtype: int64

# %%
## Find unique wind speed and its counts- it short values
data['Wind Speed_km/h'].value_counts().sort_values(ascending=True)
# Out:
# Wind Speed_km/h
# 54      1
# 83      1
# 63      1
# 70      1
# 2       2
# 50      4
# 57      5
# 52      7
# 46     11
# 43     13
# 48     13
# 44     14
# 41     22
# 39     24
# 37     45
# 35     53
# 33     85
# 32    139
# 30    161
# 28    205
# 26    242
# 0     309
# 24    374
# 22    439
# 4     474
# 20    496
# 6     609
# 19    616
# 17    666
# 7     677
# 15    719
# 13    735
# 11    791
# 9     830
# Name: count, dtype: int64

# %%
## Find how many times when the Weather is exactly 'Clear'
data.Weather.value_counts().sort_index(ascending=True)

## Ans is - Clear  1326
# Out:
# Weather
# Clear                                      1326
# Cloudy                                     1728
# Drizzle                                      41
# Drizzle,Fog                                  80
# Drizzle,Ice Pellets,Fog                       1
# Drizzle,Snow                                  2
# Drizzle,Snow,Fog                             15
# Fog                                         150
# Freezing Drizzle                              7
# Freezing Drizzle,Fog                          6
# Freezing Drizzle,Haze                         3
# Freezing Drizzle,Snow                        11
# Freezing Fog                                  4
# Freezing Rain                                14
# Freezing Rain,Fog                             4
# Freezing Rain,Haze                            2
# Freezing Rain,Ice Pellets,Fog                 1
# Freezing Rain,Snow Grains                     1
# Haze                                         16
# ...

# %%
# mask = data['Weather']=='Clear'
# new_df = data[mask]
# new_df

#####

# new_df.groupby('Weather').get_group('Clear')

# Above both code will work for similar result

# %%
mask = data['Weather']=='Clear'
new_df = data[mask]
new_df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
new_df.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
## Find how many number of times when the wind was exactly '4' km/h
data.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
data.groupby('Wind Speed_km/h').get_group(4)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
## Find out all null values of dataframe
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
## Find out all not null values of dataframe
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
## Rename the column name 'Wind Speed_km/h' to 'Wind_Speed(km/h)'
data.rename(columns= {'Wind Speed_km/h': 'Wind_Speed(km/h)'}, inplace = True) ## For permanent changes

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                 4
# 1  1/1/2012 1:00    -1.8              -3.7         87                 4
# 2  1/1/2012 2:00    -1.8              -3.4         89                 7
# 3  1/1/2012 3:00    -1.5              -3.2         88                 6
# 4  1/1/2012 4:00    -1.5              -3.3         88                 7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind_Speed(km/h)  \
# count  8784.000000       8784.000000  8784.000000       8784.000000
# mean      8.798144          2.555294    67.431694         14.945469
# std      11.687883         10.883072    16.918881          8.688696
# min     -23.300000        -28.500000    18.000000          0.000000
# 25%       0.100000         -5.900000    56.000000          9.000000
# 50%       9.300000          3.300000    68.000000         13.000000
# 75%      18.800000         11.800000    81.000000         20.000000
# max      33.000000         24.400000   100.000000         83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
## What is the mean visibility
data.Visibility_km.mean()
# Out:
# np.float64(27.664446721311478)

# %%
## What is the standard deviation of 'Pressure' in this dataframe
data.Press_kPa.std()
# Out:
# np.float64(0.8440047459486483)

# %%
## What is the variance in 'Relative Humidity' in this data??

# %%
data['Rel Hum_%'].var()
# Out:
# np.float64(286.24855019850196)

# %%
## Find all instance where 'Snow' was recorded
data[data['Weather'] == 'Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 55       1/3/2012 7:00   -14.0             -19.5         63                19
# 84      1/4/2012 12:00   -13.7             -21.7         51                11
# 86      1/4/2012 14:00   -11.3             -19.0         53                 7
# 87      1/4/2012 15:00   -10.2             -16.3         61                11
# 88      1/4/2012 16:00    -9.4             -15.5         61                13
# ...                ...     ...               ...        ...               ...
# 8779  12/31/2012 19:00     0.1              -2.7         81                30
# 8780  12/31/2012 20:00     0.2              -2.4         83                24
# 8781  12/31/2012 21:00    -0.5              -1.5         93                28
# 8782  12/31/2012 22:00    -0.2              -1.8         89                28
# 8783  12/31/2012 23:00     0.0              -2.1         86                30
#
# ...

# %%
data[data['Weather'] == 'Snow'].shape[0]
# Out:
# 390

# %%
## It gives where 'Weather' may containes 'Snow'
data[data['Weather'].str.contains('Snow')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 41      1/2/2012 17:00    -2.1              -9.5         57                22
# 44      1/2/2012 20:00    -5.6             -13.4         54                24
# 45      1/2/2012 21:00    -5.8             -12.8         58                26
# 47      1/2/2012 23:00    -7.4             -14.1         59                17
# 48       1/3/2012 0:00    -9.0             -16.0         57                28
# ...                ...     ...               ...        ...               ...
# 8779  12/31/2012 19:00     0.1              -2.7         81                30
# 8780  12/31/2012 20:00     0.2              -2.4         83                24
# 8781  12/31/2012 21:00    -0.5              -1.5         93                28
# 8782  12/31/2012 22:00    -0.2              -1.8         89                28
# 8783  12/31/2012 23:00     0.0              -2.1         86                30
#
# ...

# %%
## Find all instance where 'Wind Speed is above 24' and 'Visibility is 25'
wind_df = data[data['Wind_Speed(km/h)']> 24]

# %%
wind_df[wind_df['Visibility_km'] == 25]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 23      1/1/2012 23:00     5.3               2.0         79                30
# 24       1/2/2012 0:00     5.2               1.5         77                35
# 25       1/2/2012 1:00     4.6               0.0         72                39
# 26       1/2/2012 2:00     3.9              -0.9         71                32
# 27       1/2/2012 3:00     3.7              -1.5         69                33
# ...                ...     ...               ...        ...               ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76                26
# 8753  12/30/2012 17:00   -12.1             -15.8         74                28
# 8755  12/30/2012 19:00   -13.4             -16.5         77                26
# 8759  12/30/2012 23:00   -12.1             -15.1         78                28
# 8760   12/31/2012 0:00   -11.1             -14.4         77                26
#
# ...

# %%
data[(data['Weather'].str.contains('Snow')) & (data['Visibility_km'] == 25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 41      1/2/2012 17:00    -2.1              -9.5         57                22
# 44      1/2/2012 20:00    -5.6             -13.4         54                24
# 45      1/2/2012 21:00    -5.8             -12.8         58                26
# 48       1/3/2012 0:00    -9.0             -16.0         57                28
# 51       1/3/2012 3:00   -11.3             -18.7         54                33
# ...                ...     ...               ...        ...               ...
# 8496   12/20/2012 0:00     0.4              -2.1         83                20
# 8502   12/20/2012 6:00    -1.6              -4.2         82                15
# 8520   12/21/2012 0:00     1.9              -2.1         75                26
# 8569   12/23/2012 1:00    -7.9             -11.8         74                32
# 8587  12/23/2012 19:00    -7.2             -10.1         80                 9
#
# ...

# %%
data.head(5)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                 4
# 1  1/1/2012 1:00    -1.8              -3.7         87                 4
# 2  1/1/2012 2:00    -1.8              -3.4         89                 7
# 3  1/1/2012 3:00    -1.5              -3.2         88                 6
# 4  1/1/2012 4:00    -1.5              -3.3         88                 7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
## What is the mean value of each columns against each 'Weather'
data.groupby('Weather').mean(numeric_only=True)
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %%
## What is the minimum and maximum value of each column against each 'Weather'
data.groupby('Weather').min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
data.groupby('Weather').max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %%
## Show all record where 'Weather' Condition is 'Fog'
data[data['Weather']=='Fog']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                 4
# 1        1/1/2012 1:00    -1.8              -3.7         87                 4
# 4        1/1/2012 4:00    -1.5              -3.3         88                 7
# 5        1/1/2012 5:00    -1.4              -3.3         87                 9
# 6        1/1/2012 6:00    -1.5              -3.1         89                 7
# ...                ...     ...               ...        ...               ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                 6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                 4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                 4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                 7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                 7
#
# ...

# %%
## Show all record where 'Weather' Condition where also having 'Fog'
data[data['Weather'].str.contains('Fog')]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                 4
# 1        1/1/2012 1:00    -1.8              -3.7         87                 4
# 2        1/1/2012 2:00    -1.8              -3.4         89                 7
# 3        1/1/2012 3:00    -1.5              -3.2         88                 6
# 4        1/1/2012 4:00    -1.5              -3.3         88                 7
# ...                ...     ...               ...        ...               ...
# 8739   12/30/2012 3:00    -9.1             -10.4         90                11
# 8740   12/30/2012 4:00    -9.3             -10.6         90                13
# 8741   12/30/2012 5:00    -9.1             -10.4         90                11
# 8742   12/30/2012 6:00    -9.3             -10.8         89                17
# 8770  12/31/2012 10:00    -7.4              -8.9         89                 4
#
# ...

# %%
data.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                 4
# 1  1/1/2012 1:00    -1.8              -3.7         87                 4
# 2  1/1/2012 2:00    -1.8              -3.4         89                 7
# 3  1/1/2012 3:00    -1.5              -3.2         88                 6
# 4  1/1/2012 4:00    -1.5              -3.3         88                 7
# 5  1/1/2012 5:00    -1.4              -3.3         87                 9
# 6  1/1/2012 6:00    -1.5              -3.1         89                 7
# 7  1/1/2012 7:00    -1.4              -3.6         85                 7
# 8  1/1/2012 8:00    -1.4              -3.6         85                 9
# 9  1/1/2012 9:00    -1.3              -3.1         88                15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
## Find all instances where 'Weather' is clear or 'Visibility' is above 40

data[(data['Weather'] == 'Clear') | (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 67      1/3/2012 19:00   -16.9             -24.8         50                24
# 106     1/5/2012 10:00    -6.0             -10.0         73                17
# 107     1/5/2012 11:00    -5.6             -10.2         70                22
# 108     1/5/2012 12:00    -4.7              -9.6         69                20
# 109     1/5/2012 13:00    -4.4              -9.7         66                26
# ...                ...     ...               ...        ...               ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73                37
# 8750  12/30/2012 14:00   -11.8             -16.1         70                37
# 8751  12/30/2012 15:00   -11.3             -15.6         70                32
# 8752  12/30/2012 16:00   -11.4             -15.5         72                26
# 8756  12/30/2012 20:00   -13.8             -16.5         80                24
#
# ...

# %%
## Find all instance when 'Weather' is Clear and 'Relative Humidity' is greater than 50
data[(data['Weather'] == 'Clear') & (data['Rel Hum_%']> 50)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 114     1/5/2012 18:00    -7.1             -14.4         56                11
# 115     1/5/2012 19:00    -9.2             -15.4         61                 7
# 116     1/5/2012 20:00    -9.8             -15.7         62                 9
# 117     1/5/2012 21:00    -9.0             -14.8         63                13
# 241     1/11/2012 1:00   -10.7             -17.8         56                17
# ...                ...     ...               ...        ...               ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                 4
# 8698  12/28/2012 10:00    -6.1              -8.6         82                19
# 8713   12/29/2012 1:00   -11.9             -13.6         87                11
# 8714   12/29/2012 2:00   -11.8             -13.1         90                13
# 8756  12/30/2012 20:00   -13.8             -16.5         80                24
#
# ...

# %%
## Find all instance when 'Visbility' is above 40
data[data.Visibility_km > 40]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 106     1/5/2012 10:00    -6.0             -10.0         73                17
# 107     1/5/2012 11:00    -5.6             -10.2         70                22
# 108     1/5/2012 12:00    -4.7              -9.6         69                20
# 109     1/5/2012 13:00    -4.4              -9.7         66                26
# 110     1/5/2012 14:00    -5.1             -10.7         65                22
# ...                ...     ...               ...        ...               ...
# 8748  12/30/2012 12:00   -12.2             -15.7         75                26
# 8749  12/30/2012 13:00   -12.4             -16.2         73                37
# 8750  12/30/2012 14:00   -11.8             -16.1         70                37
# 8751  12/30/2012 15:00   -11.3             -15.6         70                32
# 8752  12/30/2012 16:00   -11.4             -15.5         72                26
#
# ...

# %%
data[data['Visibility_km'] > 40]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed(km/h)  \
# 106     1/5/2012 10:00    -6.0             -10.0         73                17
# 107     1/5/2012 11:00    -5.6             -10.2         70                22
# 108     1/5/2012 12:00    -4.7              -9.6         69                20
# 109     1/5/2012 13:00    -4.4              -9.7         66                26
# 110     1/5/2012 14:00    -5.1             -10.7         65                22
# ...                ...     ...               ...        ...               ...
# 8748  12/30/2012 12:00   -12.2             -15.7         75                26
# 8749  12/30/2012 13:00   -12.4             -16.2         73                37
# 8750  12/30/2012 14:00   -11.8             -16.1         70                37
# 8751  12/30/2012 15:00   -11.3             -15.6         70                32
# 8752  12/30/2012 16:00   -11.4             -15.5         72                26
#
# ...
