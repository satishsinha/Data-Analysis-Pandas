# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('CovidDataAnalysis.csv')

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count() ## data.isnull().sum()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data['State'] = data['State'].fillna('Not Available')

# %%
data
# Out:
#           Date          State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020  Not Available     Afghanistan       1939      60        252
# 1    4/29/2020  Not Available         Albania        766      30        455
# 2    4/29/2020  Not Available         Algeria       3848     444       1702
# 3    4/29/2020  Not Available         Andorra        743      42        423
# 4    4/29/2020  Not Available          Angola         27       2          7
# ..         ...            ...             ...        ...     ...        ...
# 316  4/29/2020        Wyoming              US        545       7          0
# 317  4/29/2020       Xinjiang  Mainland China         76       3         73
# 318  4/29/2020          Yukon          Canada         11       0          0
# 319  4/29/2020         Yunnan  Mainland China        185       2        181
# 320  4/29/2020       Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count()
# Out:
# Date         321
# State        321
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.groupby('Region').sum()
# Out:
#                          Date          State  Confirmed  Deaths  Recovered
# Region
# Afghanistan         4/29/2020  Not Available       1939      60        252
# Albania             4/29/2020  Not Available        766      30        455
# Algeria             4/29/2020  Not Available       3848     444       1702
# Andorra             4/29/2020  Not Available        743      42        423
# Angola              4/29/2020  Not Available         27       2          7
# ...                       ...            ...        ...     ...        ...
# West Bank and Gaza  4/29/2020  Not Available        344       2         71
# Western Sahara      4/29/2020  Not Available          6       0          5
# Yemen               4/29/2020  Not Available          6       0          1
# Zambia              4/29/2020  Not Available         97       3         54
# Zimbabwe            4/29/2020  Not Available         32       4          5
#
# [187 rows x 5 columns]

# %%
## Show the number of Confirmed, Death and Recovered cases in each region
data.groupby('Region')[['Confirmed', 'Deaths', 'Recovered']].sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
sns.heatmap(data.groupby('Region')[['Confirmed', 'Deaths', 'Recovered']].sum())
# Out:
# <Axes: ylabel='Region'>

# %%
## Remove all the records where Confirmed case is less than 10
min_confirmed = data[~(data.Confirmed < 11)]

# %%
min_confirmed
# Out:
#           Date          State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020  Not Available     Afghanistan       1939      60        252
# 1    4/29/2020  Not Available         Albania        766      30        455
# 2    4/29/2020  Not Available         Algeria       3848     444       1702
# 3    4/29/2020  Not Available         Andorra        743      42        423
# 4    4/29/2020  Not Available          Angola         27       2          7
# ..         ...            ...             ...        ...     ...        ...
# 316  4/29/2020        Wyoming              US        545       7          0
# 317  4/29/2020       Xinjiang  Mainland China         76       3         73
# 318  4/29/2020          Yukon          Canada         11       0          0
# 319  4/29/2020         Yunnan  Mainland China        185       2        181
# 320  4/29/2020       Zhejiang  Mainland China       1268       1       1263
#
# [301 rows x 6 columns]

# %%
data.groupby('Region').sum().Confirmed.sort_values(ascending=False).head()
# Out:
# Region
# US        1039909
# Spain      236899
# Italy      203591
# France     166536
# UK         166432
# Name: Confirmed, dtype: int64

# %%
## In which region, maximum number of death recorded
data.head()
# Out:
#         Date          State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020  Not Available  Afghanistan       1939      60        252
# 1  4/29/2020  Not Available      Albania        766      30        455
# 2  4/29/2020  Not Available      Algeria       3848     444       1702
# 3  4/29/2020  Not Available      Andorra        743      42        423
# 4  4/29/2020  Not Available       Angola         27       2          7

# %%
data.groupby('Region').sum().Deaths.sort_values(ascending=False).head()
# Out:
# Region
# US        60967
# Italy     27682
# UK        26165
# Spain     24275
# France    24121
# Name: Deaths, dtype: int64

# %%
## How many Confirmed, Deaths and recovered cases where reported from INDIA till 29 April 2020
data[data['Region'] == 'India']
# Out:
#          Date          State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020  Not Available  India      33062    1079       8437

# %%
## Sort the entire data with respect to No. of confirmed cases in ascending order
data.sort_values(by = ['Confirmed'], ascending=True)
# Out:
#           Date          State      Region  Confirmed  Deaths  Recovered
# 27   4/29/2020  Not Available     Burundi         11       1          4
# 318  4/29/2020          Yukon      Canada         11       0          0
# 217  4/29/2020      Greenland     Denmark         11       0         11
# 144  4/29/2020  Not Available  Seychelles         11       0          6
# 256  4/29/2020     Montserrat          UK         11       1          2
# ..         ...            ...         ...        ...     ...        ...
# 57   4/29/2020  Not Available      France     165093   24087      48228
# 168  4/29/2020  Not Available          UK     165221   26097          0
# 80   4/29/2020  Not Available       Italy     203591   27682      71252
# 153  4/29/2020  Not Available       Spain     236899   24275     132929
# 265  4/29/2020       New York          US     299691   23477          0
#
# [301 rows x 6 columns]

# %%
## Sort the entire data with respect to no. of recovered cases in descending order
data.sort_values(by = ['Recovered'], ascending=False)
# Out:
#           Date          State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020  Not Available           Spain     236899   24275     132929
# 61   4/29/2020  Not Available         Germany     161539    6467     120400
# 76   4/29/2020  Not Available            Iran      93657    5957      73791
# 80   4/29/2020  Not Available           Italy     203591   27682      71252
# 229  4/29/2020          Hubei  Mainland China      68128    4512      63616
# ..         ...            ...             ...        ...     ...        ...
# 253  4/29/2020    Mississippi              US       6569     250          0
# 252  4/29/2020      Minnesota              US       4644     319          0
# 251  4/29/2020       Michigan              US      40399    3670          0
# 187  4/29/2020       Arkansas              US       3193      57          0
# 186  4/29/2020        Arizona              US       7209     308          0
#
# [301 rows x 6 columns]
